# %% [markdown]
# ## Importing required libries

# %%
# importing required libraries
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading the dataset

# %%
df = pd.read_csv(r"C:\Users\omkar\Downloads\hour.csv")
df
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 0            1  2011-01-01       1   0     1   0        0        6
# 1            2  2011-01-01       1   0     1   1        0        6
# 2            3  2011-01-01       1   0     1   2        0        6
# 3            4  2011-01-01       1   0     1   3        0        6
# 4            5  2011-01-01       1   0     1   4        0        6
# ...        ...         ...     ...  ..   ...  ..      ...      ...
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 0               0           1  0.24  0.2879  0.81     0.0000       3
# ...

# %%
df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %% [markdown]
# The df.describe() method in pandas is used to generate descriptive statistics of a DataFrame. It provides a summary of the central tendency, dispersion, and shape of the distribution of a dataset.
#
# Count: Number of non-null values in each column.
# Mean: Mean or average value of each column.
# std: Standard deviation, a measure of the amount of variation or dispersion of each column.
# min: Minimum value in each column.
# 25%: First quartile, also known as the 25th percentile.
# 50% (median): Second quartile or median, the middle value of each column.
# 75%: Third quartile, also known as the 75th percentile.
# max: Maximum value in each column.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %% [markdown]
# The df.info() method in pandas is used to display a concise summary of a DataFrame, including information about the data
# types, non-null values, and memory usage.
#
# Index: RangeIndex or MultiIndex, indicating the index labels.
# Columns: Names of the columns in the DataFrame.
# dtypes: Data types of each column.
# Non-Null Count: Number of non-null (non-missing) values in each column.
# Memory Usage: The amount of memory used by the DataFrame.

# %% [markdown]
# ## Cheking for null values

# %%
df.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# No null value present in the dataset

# %% [markdown]
# ## cheking for duplicate values

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head() # cheking head rows
# Out:
#    instant  season  yr  mnth  hr  holiday  weekday  workingday  weathersit  \
# 0        1       1   0     1   0        0        6           0           1
# 1        2       1   0     1   1        0        6           0           1
# 2        3       1   0     1   2        0        6           0           1
# 3        4       1   0     1   3        0        6           0           1
# 4        5       1   0     1   4        0        6           0           1
#
#    temp   atemp   hum  windspeed  casual  registered  cnt
# 0  0.24  0.2879  0.81        0.0       3          13   16
# 1  0.22  0.2727  0.80        0.0       8          32   40
# 2  0.22  0.2727  0.80        0.0       5          27   32
# 3  0.24  0.2879  0.75        0.0       3          10   13
# 4  0.24  0.2879  0.75        0.0       0           1    1

# %%
df.iloc[1:,1:].corr() # correlation between the features
# Out:
#               season        yr      mnth        hr   holiday   weekday  \
# season      1.000000 -0.009315  0.832752 -0.003227 -0.011808  0.000112
# yr         -0.009315  1.000000 -0.010526 -0.003738  0.008984 -0.003981
# mnth        0.832752 -0.010526  1.000000 -0.001907  0.015354  0.010297
# hr         -0.003227 -0.003738 -0.001907  1.000000  0.000933 -0.003937
# holiday    -0.011808  0.008984  0.015354  0.000933  1.000000 -0.103630
# weekday     0.000112 -0.003981  0.010297 -0.003937 -0.103630  1.000000
# workingday  0.013644 -0.003410 -0.000854  0.002209 -0.253247  0.040602
# weathersit -0.021252 -0.017396  0.000615 -0.022028 -0.015785  0.004496
# temp        0.307392  0.042404  0.198509  0.139348 -0.027234  0.000610
# atemp       0.313582  0.040898  0.204370  0.136277 -0.030849 -0.006637
# hum         0.138750 -0.083197  0.155413 -0.276738 -0.011402 -0.034110
# windspeed  -0.127965 -0.010939 -0.121084  0.131963  0.006913  0.005759
# ...

# %% [markdown]
# ## Visualazation

# %% [markdown]
# ## Heatmap for correlation

# %%
sns.set(rc = {'figure.figsize':(15,8)})
sns.heatmap(df.iloc[1:,1:].corr(),annot = True)
# Out:
# <Axes: >

# %%
 sns.barplot(x = "season",
            y = "cnt",
            data = df,
            palette = "Reds")
# Out:
# C:\Users\omkar\AppData\Local\Temp\ipykernel_19028\736845463.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = "season",
# <Axes: xlabel='season', ylabel='cnt'>

# %%
df.columns.tolist() # columns names
# Out:
# ['instant',
#  'season',
#  'yr',
#  'mnth',
#  'hr',
#  'holiday',
#  'weekday',
#  'workingday',
#  'weathersit',
#  'temp',
#  'atemp',
#  'hum',
#  'windspeed',
#  'casual',
#  'registered',
#  'cnt']

# %% [markdown]
# Name of all columns present in the dataset

# %% [markdown]
# ## Pairplot
# it shows how data point is scattered

# %%
name = df[['season','mnth','cnt']]
sns.pairplot(name,diag_kind = 'kde')
plt.show()

# %%
name_1 = df[['weathersit','temp','atemp','hum','windspeed','cnt']]
sns.pairplot(name,diag_kind = 'kde')
plt.show()

# %%
'casual','registered','hr','holiday','weekday','workingday',
# Out:
# ('casual', 'registered', 'hr', 'holiday', 'weekday', 'workingday')

# %%
sns.barplot(x = "holiday",
            y = "cnt",
            data = df,
            palette = "Greens")
# Out:
# C:\Users\omkar\AppData\Local\Temp\ipykernel_19028\1460749362.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = "holiday",
# <Axes: xlabel='holiday', ylabel='cnt'>

# %%
plt.subplot(4, 3, 1)
fig = df.boxplot(column='casual')
fig.set_title('')
fig.set_ylabel('casual')

plt.subplot(4, 3, 2)
fig = df.boxplot(column='registered')
fig.set_title('')
fig.set_ylabel('registered')

plt.subplot(4, 3, 3)
fig = df.boxplot(column='hr')
fig.set_title('')
fig.set_ylabel('hr')

plt.subplot(4, 3, 4)
fig = df.boxplot(column='windspeed')
fig.set_title('')
fig.set_ylabel('windspeed')

plt.subplot(4, 3, 5)
fig = df.boxplot(column='hum')
fig.set_title('')
fig.set_ylabel('hum')


plt.subplot(4, 3, 6)
fig = df.boxplot(column='temp')
fig.set_title('')
fig.set_ylabel('temp')

plt.subplot(4, 3, 7)
fig = df.boxplot(column='weathersit')
fig.set_title('')
fig.set_ylabel('weathersit')
# Out:
# Text(0, 0.5, 'weathersit')

# %% [markdown]
# It show that outliers are present in dataset or not we have outliers present in weendspeed featutre we neet to deal with that

# %%
# Calculate Quartiles and IQR
Q1 = df.windspeed.quantile(0.25)
Q3 = df.windspeed.quantile(0.75)
IQR = Q3 - Q1
# Outlier Filtering
filtered_data = df.windspeed[~((df.windspeed < (Q1 - 1.5 * IQR)) | (df.windspeed > (Q3 + 1.5 * IQR)))]

# %%
filtered_data # # Filtered Data
# Out:
# 0        0.0000
# 1        0.0000
# 2        0.0000
# 3        0.0000
# 4        0.0000
#           ...
# 17374    0.1642
# 17375    0.1642
# 17376    0.1642
# 17377    0.1343
# 17378    0.1343
# Name: windspeed, Length: 17037, dtype: float64

# %%
df.windspeed # Show thw values from weendspeed column
# Out:
# 0        0.0000
# 1        0.0000
# 2        0.0000
# 3        0.0000
# 4        0.0000
#           ...
# 17374    0.1642
# 17375    0.1642
# 17376    0.1642
# 17377    0.1343
# 17378    0.1343
# Name: windspeed, Length: 17379, dtype: float64

# %%
fig = df.boxplot(column='windspeed')
fig.set_title('')
fig.set_ylabel('windspeed')
# Out:
# Text(0, 0.5, 'windspeed')

# %% [markdown]
# Box plot for the specific weendspeed column to check the outliers

# %% [markdown]
# This code calculates the upper bound for outliers in the 'windspeed' column using the IQR method and prints the upper bound value along with the count of values exceeding this upper bound.

# %%
# Calculate upper bound for outliers
upper = Q3+1.5*IQR
# Create a boolean array identifying values exceeding the upper bound
upper_array = np.array(df['windspeed'] >= upper)
# Print upper bound and count of values exceeding it
print("Upper Bound:", upper)
print(upper_array.sum())
# Out:
# Upper Bound: 0.4775
# 0

# %% [markdown]
# This code calculates the lower bound for outliers in the 'windspeed' column using the IQR method and prints the lower bound value along with the count of values below this lower bound

# %%
# Calculate lower bound for outliers
lower = Q1-1.5*IQR
# Create a boolean array identifying values below the lower bound
lower_array = np.array(df['windspeed'] <= lower)
# Print lower bound and count of values below it
print("Lower Bound:", lower)
print(lower_array.sum())
# Out:
# Lower Bound: -0.1193
# 0

# %%
''' Detection '''
# IQR
# Calculate the upper and lower limits
Q1 = df['windspeed'].quantile(0.25)
Q3 = df['windspeed'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5*IQR
upper = Q3 + 1.5*IQR

# %%
# Create arrays of Boolean values indicating the outlier rows
upper_array = np.where(df['windspeed'] >= upper)[0]
lower_array = np.where(df['windspeed'] <= lower)[0]

# %%
# Removing the outliers
df.drop(index=upper_array, inplace=True)
df.drop(index=lower_array, inplace=True)

# %%
print("New Shape: ", df.shape)
# Out:
# New Shape:  (17037, 16)

# %%
fig = df.boxplot(column='windspeed')
fig.set_title('')
fig.set_ylabel('windspeed')
# Out:
# Text(0, 0.5, 'windspeed')

# %% [markdown]
# Now here we removed the outliers

# %%
df.windspeed
# Out:
# 0        0.0000
# 1        0.0000
# 2        0.0000
# 3        0.0000
# 4        0.0000
#           ...
# 17374    0.1642
# 17375    0.1642
# 17376    0.1642
# 17377    0.1343
# 17378    0.1343
# Name: windspeed, Length: 17037, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
#from sklearn.preprocessing import StandardScaler
Scalar =StandardScaler()

# %%
x=df.drop(["cnt"], axis = 1)
y = df['cnt']

# %% [markdown]
# ## Spliting data into training and testing data

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %% [markdown]
# ## Model Selection
#
# This code snippet uses the scikit-learn library to train a RandomForestClassifier on training data (x_train and y_train) and then make predictions on test data (x_test)

# %%
# Import the RandomForestClassifier from scikit-learn
from sklearn.ensemble import RandomForestClassifier
# Create an variable of the RandomForestClassifier
rfc = RandomForestClassifier()
# Train the RandomForestClassifier on the training data
rfc.fit(x_train,y_train)
# Make predictions on the test data
y_pred = rfc.predict(x_test)

# %%
y_pred
# Out:
# array([239, 812, 684, ...,  10, 596,  96], dtype=int64)

# %%
# Import the r2_score function from scikit-learn metrics
from sklearn.metrics import r2_score
# Calculate the R-squared accuracy score
accuracy = r2_score(y_test, y_pred)

# %% [markdown]
# The r2_score function from scikit-learn to calculate the R-squared (coefficient of determination) metric to assess the accuracy of predictions

# %%
accuracy
# Out:
# 0.9364212199153831
